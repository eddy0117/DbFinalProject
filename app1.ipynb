# %%
from flask_sqlalchemy import SQLAlchemy
from flask import Flask
from models import db, Song, User, Playlist, Artist
from methods import *
app = Flask(__name__)

app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///db.sqlite3'
db.init_app(app)


with app.app_context():
    # print(search_song(db, 'a'))
    # add_user(db, 'user1', '123')
    # for it in [1, 2, 3, 4, 5, 6]:
        # add_playlist(db, 1, '我的播放清單' + str(it))
    # for it in ['abc', 'bcd', 'cde', 'dea', 'eab']:
    #     add_song(db, it, '1', '2999', '29', 'A1', 'A2')
    for it in [1, 2, 3]:
        add_song_to_playlist(db, 1, it)
    # del_song_from_playlist(db, 3, 3)
    # add_user(db, 'user2', '345')
    # add_playlist(db, 'user2')
    # del_playlist(db, 3)
    # del_song(db, 2)
    # add_song(db, 'e1e123123eee', 'y1y123yy3y', '2021', '220', 'a1', 'a2', 'a3', 'a4', 'a5')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File d:\Miniconda3\envs\react\lib\site-packages\sqlalchemy\engine\base.py:1971, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1970     if not evt_handled:
# -> 1971         self.dialect.do_execute(
#    1972             cursor, str_statement, effective_parameters, context
#    1973         )
#    1975 if self._has_events or self.engine._has_events:
#
# File d:\Miniconda3\envs\react\lib\site-packages\sqlalchemy\engine\default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: songlist.PlaylistID, songlist.SongID
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
with app.app_context():
    search_song(db, 'a')
# Out:
# a

# %%
user.Playlist
# Out:
# [<Playlist 2>]

# %%
import time
time.strftime('%Y-%m-%d %H:%M:%S', time.localtime())
# Out:
# '2024-05-04 11:39:20'
